# %%
j = sqrt(Complex(-1))
# Out:
# 0.0 + 1.0im

# %%
# Define the complex numbers representing the signal
signal = [
    -0.71 + 0.71j, -0.71 + 0.71j, -0.71 + 0.71j, -0.71 - 0.71j, 0.71 - 0.71j, 
    -0.71 - 0.71j, 0.71 + 0.71j, 0.71 + 0.71j, -0.71 - 0.71j, 0.71 + 0.71j, 
    0.71 - 0.71j, -0.71 + 0.71j, -0.71 - 0.71j, -0.71 + 0.71j, -0.71 + 0.71j, 
    -0.71 - 0.71j, 0.71 - 0.71j, 0.71 + 0.71j, 0.71 + 0.71j, -0.71 + 0.71j, 
    -0.71 + 0.71j, 0.71 + 0.71j, -0.71 + 0.71j, -0.71 + 0.71j, 0.71 + 0.71j, 
    0.71 + 0.71j, -0.71 + 0.71j, -0.71 - 0.71j, 0.71 - 0.71j, 0.71 - 0.71j, 
    -0.71 - 0.71j, 0.71 - 0.71j, -0.71 - 0.71j, -0.71 + 0.71j, 0.71 + 0.71j, 
    0.71 + 0.71j, 0.71 - 0.71j, 0.71 + 0.71j, 0.71 + 0.71j, 0.71 - 0.71j, 
    -0.71 + 0.71j, -0.71 - 0.71j, 0.71 + 0.71j, -0.71 - 0.71j, 0.71 - 0.71j, 
    0.71 + 0.71j, -0.71 - 0.71j, 0.71 + 0.71j, 0.71 - 0.71j, 0.71 + 0.71j
];

# %%
@show signal;
# Out:
# signal = ComplexF64[-0.71 + 0.71im, -0.71 + 0.71im, -0.71 + 0.71im, -0.71 - 0.71im, 0.71 - 0.71im, -0.71 - 0.71im, 0.71 + 0.71im, 0.71 + 0.71im, -0.71 - 0.71im, 0.71 + 0.71im, 0.71 - 0.71im, -0.71 + 0.71im, -0.71 - 0.71im, -0.71 + 0.71im, -0.71 + 0.71im, -0.71 - 0.71im, 0.71 - 0.71im, 0.71 + 0.71im, 0.71 + 0.71im, -0.71 + 0.71im, -0.71 + 0.71im, 0.71 + 0.71im, -0.71 + 0.71im, -0.71 + 0.71im, 0.71 + 0.71im, 0.71 + 0.71im, -0.71 + 0.71im, -0.71 - 0.71im, 0.71 - 0.71im, 0.71 - 0.71im, -0.71 - 0.71im, 0.71 - 0.71im, -0.71 - 0.71im, -0.71 + 0.71im, 0.71 + 0.71im, 0.71 + 0.71im, 0.71 - 0.71im, 0.71 + 0.71im, 0.71 + 0.71im, 0.71 - 0.71im, -0.71 + 0.71im, -0.71 - 0.71im, 0.71 + 0.71im, -0.71 - 0.71im, 0.71 - 0.71im, 0.71 + 0.71im, -0.71 - 0.71im, 0.71 + 0.71im, 0.71 - 0.71im, 0.71 + 0.71im]

# %%
using Plots

# %%
# Extract real and imaginary parts
real_parts = real(signal)
imag_parts = imag(signal)

# Create a scatter plot
scatter(real_parts, imag_parts, xlabel="In-Phase", ylabel="Quadrature", title="Constellation Diagram", legend=false, aspect_ratio=:equal)

# Display the plot
display(plot!())

# %%
# Define the time indices for the signal
time_indices = 1:length(signal)

# Extract real and imaginary parts
real_parts = real(signal)
imag_parts = imag(signal)

# Create a plot for the real part of the signal
plot(time_indices, real_parts, label="Real Part", xlabel="Time", ylabel="Amplitude", title="PDSCH Signal in Time Domain")
# Add the imaginary part of the signal to the plot
plot!(time_indices, imag_parts, label="Imaginary Part")

# Display the plot
display(plot!())

# %% [markdown]
# # References
# - [ ] [Toolbox: PDSCH signal generator](https://www.nrexplained.com/pdschmod)
